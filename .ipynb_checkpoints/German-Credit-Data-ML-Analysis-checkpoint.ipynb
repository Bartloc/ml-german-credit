# %%
# %matplotlib inline 
import matplotlib.pyplot as plt 

import numpy as np ; np.random.seed(sum(map(ord, "aesthetics")))
import pandas as pd

from sklearn.metrics import classification_report,confusion_matrix, roc_curve, roc_auc_score, auc, accuracy_score

# %% [markdown]
# SOME IMPORTANT FUNCTIONS

# %%
def plot_roc_curve(fpr, tpr,auc):
    plt.plot(fpr, tpr, color='orange', label='ROC -AUC %.2f' %auc)
    plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend()
    plt.show()
def analize_data(X_text,y_test,predictions,probs):
    print(pd.DataFrame(confusion_matrix(y_test, predictions), 
             columns=['Predicted Negative', 'Predicted Positive'], 
             index=['Actual Negative', 'Actual Positive']))
    print("\n")
    print(classification_report(y_test,predictions))
    probs=probs[:,1]
    auc = roc_auc_score(y_test, probs)
   
    fpr, tpr, thresholds = roc_curve(y_test, probs)
    plot_roc_curve(fpr, tpr,auc)

def plot_hist(classification,hist_value,data,bins,size,numeric=False):
    plt.figure(figsize=size)
    if numeric:
        plt.xticks(np.arange(0, max(data[hist_value]), max(data[hist_value]/20)))
    data[data[classification]==0][hist_value].hist(alpha=0.9,color='red',bins=bins)
    data[data[classification]==1][hist_value].hist(alpha=0.3,color='blue',bins=bins)

# %%
file = 'C:\\Users\\Forex1\\Desktop\\AI\\ml-german-credit\\data\\german.data'


names = ['existingchecking', 'duration', 'credithistory', 'purpose', 'creditamount', 
         'savings', 'employmentsince', 'installmentrate', 'statussex', 'otherdebtors', 
         'residencesince', 'property', 'age', 'otherinstallmentplans', 'housing', 
         'existingcredits', 'job', 'peopleliable', 'telephone', 'foreignworker', 'classification']

data = pd.read_csv(file,names = names, delimiter=' ')
print(data.shape)
print (data.columns)
data.head(10)
# Out:
# (1000, 21)
# Index(['existingchecking', 'duration', 'credithistory', 'purpose',
#        'creditamount', 'savings', 'employmentsince', 'installmentrate',
#        'statussex', 'otherdebtors', 'residencesince', 'property', 'age',
#        'otherinstallmentplans', 'housing', 'existingcredits', 'job',
#        'peopleliable', 'telephone', 'foreignworker', 'classification'],
#       dtype='object')
#   existingchecking  duration credithistory purpose  creditamount savings  \
# 0              A11         6           A34     A43          1169     A65
# 1              A12        48           A32     A43          5951     A61
# 2              A14        12           A34     A46          2096     A61
# 3              A11        42           A32     A42          7882     A61
# 4              A11        24           A33     A40          4870     A61
# 5              A14        36           A32     A46          9055     A65
# 6              A14        24           A32     A42          2835     A63
# 7              A12        36           A32     A41          6948     A61
# 8              A14        12           A32     A43          3059     A64
# 9              A12        30           A34     A40          5234     A61
#
#   employmentsince  installmentrate statussex otherdebtors  ...  property age  \
# 0             A75                4       A93         A101  ...      A121  67
# 1             A73                2       A92         A101  ...      A121  22
# 2             A74                2       A93         A101  ...      A121  49
# 3             A74                2       A93         A103  ...      A122  45
# 4             A73                3       A93         A101  ...      A124  53
# 5             A73                2       A93         A101  ...      A124  35
# 6             A75                3       A93         A101  ...      A122  53
# 7             A73                2       A93         A101  ...      A123  35
# 8             A74                2       A91         A101  ...      A121  61
# 9             A71                4       A94         A101  ...      A123  28
#
#    otherinstallmentplans housing existingcredits   job peopleliable  \
# 0                   A143    A152               2  A173            1
# 1                   A143    A152               1  A173            1
# 2                   A143    A152               1  A172            2
# 3                   A143    A153               1  A173            2
# 4                   A143    A153               2  A173            2
# 5                   A143    A153               1  A172            2
# 6                   A143    A152               1  A173            1
# 7                   A143    A151               1  A174            1
# 8                   A143    A152               1  A172            1
# 9                   A143    A152               2  A174            1
#
#    telephone foreignworker classification
# 0       A192          A201              1
# 1       A191          A201              2
# 2       A191          A201              1
# 3       A191          A201              1
# 4       A191          A201              2
# 5       A192          A201              1
# 6       A191          A201              1
# 7       A192          A201              1
# 8       A191          A201              1
# 9       A191          A201              2
#
# [10 rows x 21 columns]

# %%
data['classification'].replace([1,2], [1,0], inplace=True)
data['classification'].value_counts()
# Out:
# 1    700
# 0    300
# Name: classification, dtype: int64

# %% [markdown]
# For simplify binary classification
#
# 0 - BAD CLIENT
# 1 -GOOD CLIENT

# %%
from sklearn.preprocessing import StandardScaler

# %%
#numerical variables labels
numvars = ['creditamount', 'duration', 'installmentrate', 'residencesince', 'age', 
           'existingcredits', 'peopleliable']

# %%
data[numvars].describe()
# Out:
#        creditamount     duration  installmentrate  residencesince  \
# count   1000.000000  1000.000000      1000.000000     1000.000000
# mean    3271.258000    20.903000         2.973000        2.845000
# std     2822.736876    12.058814         1.118715        1.103718
# min      250.000000     4.000000         1.000000        1.000000
# 25%     1365.500000    12.000000         2.000000        2.000000
# 50%     2319.500000    18.000000         3.000000        3.000000
# 75%     3972.250000    24.000000         4.000000        4.000000
# max    18424.000000    72.000000         4.000000        4.000000
#
#                age  existingcredits  peopleliable
# count  1000.000000      1000.000000   1000.000000
# mean     35.546000         1.407000      1.155000
# std      11.375469         0.577654      0.362086
# min      19.000000         1.000000      1.000000
# 25%      27.000000         1.000000      1.000000
# 50%      33.000000         1.000000      1.000000
# 75%      42.000000         2.000000      1.000000
# max      75.000000         4.000000      2.000000

# %%
# Standardization
numdata_std = pd.DataFrame(StandardScaler().fit_transform(data[numvars]),columns=numvars)
numdata_std
# Out:
#      creditamount  duration  installmentrate  residencesince       age  \
# 0       -0.745131 -1.236478         0.918477        1.046987  2.766456
# 1        0.949817  2.248194        -0.870183       -0.765977 -1.191404
# 2       -0.416562 -0.738668        -0.870183        0.140505  1.183312
# 3        1.634247  1.750384        -0.870183        1.046987  0.831502
# 4        0.566664  0.256953         0.024147        1.046987  1.535122
# ..            ...       ...              ...             ...       ...
# 995     -0.544162 -0.738668         0.024147        1.046987 -0.399832
# 996      0.207612  0.754763         0.918477        1.046987  0.391740
# 997     -0.874503 -0.738668         0.918477        1.046987  0.215835
# 998     -0.505528  1.999289         0.918477        1.046987 -1.103451
# 999      0.462457  1.999289         0.024147        1.046987 -0.751642
#
#      existingcredits  peopleliable
# 0           1.027079     -0.428290
# 1          -0.704926     -0.428290
# 2          -0.704926      2.334869
# 3          -0.704926      2.334869
# 4           1.027079      2.334869
# ..               ...           ...
# 995        -0.704926     -0.428290
# 996        -0.704926     -0.428290
# 997        -0.704926     -0.428290
# 998        -0.704926     -0.428290
# 999        -0.704926     -0.428290
#
# [1000 rows x 7 columns]

# %%
from collections import defaultdict
from sklearn.preprocessing import LabelEncoder

#categorical variables labels
catvars = ['existingchecking', 'credithistory', 'purpose', 'savings', 'employmentsince',
           'statussex', 'otherdebtors', 'property', 'otherinstallmentplans', 'housing', 'job', 
           'telephone', 'foreignworker']

d = defaultdict(LabelEncoder)

# Encoding the variable
lecatdata = data[catvars].apply(lambda x: d[x.name].fit_transform(x))
lecatdata =pd.DataFrame(StandardScaler().fit_transform(lecatdata),columns=catvars)

# %%
data_prep = pd.concat([numdata_std, lecatdata,data['classification']], axis = 1)

# %%
data_prep
# Out:
#      creditamount  duration  installmentrate  residencesince       age  \
# 0       -0.745131 -1.236478         0.918477        1.046987  2.766456
# 1        0.949817  2.248194        -0.870183       -0.765977 -1.191404
# 2       -0.416562 -0.738668        -0.870183        0.140505  1.183312
# 3        1.634247  1.750384        -0.870183        1.046987  0.831502
# 4        0.566664  0.256953         0.024147        1.046987  1.535122
# ..            ...       ...              ...             ...       ...
# 995     -0.544162 -0.738668         0.024147        1.046987 -0.399832
# 996      0.207612  0.754763         0.918477        1.046987  0.391740
# 997     -0.874503 -0.738668         0.918477        1.046987  0.215835
# 998     -0.505528  1.999289         0.918477        1.046987 -1.103451
# 999      0.462457  1.999289         0.024147        1.046987 -0.751642
#
#      existingcredits  peopleliable  existingchecking  credithistory   purpose  \
# 0           1.027079     -0.428290         -1.254566       1.344014  0.264068
# 1          -0.704926     -0.428290         -0.459026      -0.503428  0.264068
# 2          -0.704926      2.334869          1.132053       1.344014  1.359785
# 3          -0.704926      2.334869         -1.254566      -0.503428 -0.101171
# 4           1.027079      2.334869         -1.254566       0.420293 -1.196889
# ..               ...           ...               ...            ...       ...
# 995        -0.704926     -0.428290          1.132053      -0.503428 -0.101171
# 996        -0.704926     -0.428290         -1.254566      -0.503428 -0.831650
# 997        -0.704926     -0.428290          1.132053      -0.503428  0.264068
# 998        -0.704926     -0.428290         -1.254566      -0.503428  0.264068
# 999        -0.704926     -0.428290         -0.459026       1.344014 -0.831650
#
#      ...  employmentsince  statussex  otherdebtors  property  \
# 0    ...         1.338078   0.449326     -0.303686 -1.293723
# 1    ...        -0.317959  -0.963650     -0.303686 -1.293723
# 2    ...         0.510060   0.449326     -0.303686 -1.293723
# 3    ...         0.510060   0.449326      3.885083 -0.341055
# 4    ...        -0.317959   0.449326     -0.303686  1.564281
# ..   ...              ...        ...           ...       ...
# 995  ...         0.510060  -0.963650     -0.303686 -1.293723
# 996  ...        -0.317959  -2.376626     -0.303686 -0.341055
# 997  ...         1.338078   0.449326     -0.303686  0.611613
# 998  ...        -0.317959   0.449326     -0.303686  1.564281
# 999  ...        -1.973997   0.449326     -0.303686  0.611613
#
#      otherinstallmentplans   housing       job  telephone  foreignworker  \
# 0                 0.460831  0.133710  0.146949   1.214598      -0.196014
# 1                 0.460831  0.133710  0.146949  -0.823318      -0.196014
# 2                 0.460831  0.133710 -1.383771  -0.823318      -0.196014
# 3                 0.460831  2.016956  0.146949  -0.823318      -0.196014
# 4                 0.460831  2.016956  0.146949  -0.823318      -0.196014
# ..                     ...       ...       ...        ...            ...
# 995               0.460831  0.133710 -1.383771  -0.823318      -0.196014
# 996               0.460831  0.133710  1.677670   1.214598      -0.196014
# 997               0.460831  0.133710  0.146949  -0.823318      -0.196014
# 998               0.460831  2.016956  0.146949   1.214598      -0.196014
# 999               0.460831  0.133710  0.146949  -0.823318      -0.196014
#
#      classification
# 0                 1
# 1                 0
# 2                 1
# 3                 1
# 4                 0
# ..              ...
# 995               1
# 996               1
# 997               1
# 998               0
# 999               1
#
# [1000 rows x 21 columns]

# %%
from sklearn.model_selection import train_test_split  

X = data_prep.drop('classification', axis=1)
y = data_prep['classification']
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=111)

# %%
y_test.value_counts()
# Out:
# 1    139
# 0     61
# Name: classification, dtype: int64

# %%
from sklearn.neural_network import MLPClassifier 
mlp = MLPClassifier(hidden_layer_sizes=(100,40,100), max_iter=1000,verbose=True)  
mlp.fit(X_train, y_train.values.reshape(-1))
# Out:
# Iteration 1, loss = 0.73264845
# Iteration 2, loss = 0.66813643
# Iteration 3, loss = 0.62963596
# Iteration 4, loss = 0.60430152
# Iteration 5, loss = 0.58751472
# Iteration 6, loss = 0.57076849
# Iteration 7, loss = 0.55299410
# Iteration 8, loss = 0.53708657
# Iteration 9, loss = 0.52224170
# Iteration 10, loss = 0.50935516
# Iteration 11, loss = 0.49726481
# Iteration 12, loss = 0.48586172
# Iteration 13, loss = 0.47732525
# Iteration 14, loss = 0.46847489
# Iteration 15, loss = 0.45999236
# Iteration 16, loss = 0.45284869
# Iteration 17, loss = 0.44593682
# Iteration 18, loss = 0.43858608
# Iteration 19, loss = 0.43080631
# Iteration 20, loss = 0.42393515
# Iteration 21, loss = 0.41663363
# Iteration 22, loss = 0.40907859
# Iteration 23, loss = 0.40225593
# Iteration 24, loss = 0.39284007
# Iteration 25, loss = 0.38528544
# Iteration 26, loss = 0.37572099
# Iteration 27, loss = 0.36664487
# Iteration 28, loss = 0.35772747
# Iteration 29, loss = 0.34707667
# Iteration 30, loss = 0.33791683
# Iteration 31, loss = 0.32794870
# Iteration 32, loss = 0.31905696
# Iteration 33, loss = 0.30741668
# Iteration 34, loss = 0.29625157
# Iteration 35, loss = 0.28461556
# Iteration 36, loss = 0.27459896
# Iteration 37, loss = 0.26354316
# Iteration 38, loss = 0.25307785
# Iteration 39, loss = 0.24199528
# Iteration 40, loss = 0.23155238
# Iteration 41, loss = 0.22157704
# Iteration 42, loss = 0.20903368
# Iteration 43, loss = 0.20164135
# Iteration 44, loss = 0.18893147
# Iteration 45, loss = 0.18157685
# Iteration 46, loss = 0.16975413
# Iteration 47, loss = 0.15911261
# Iteration 48, loss = 0.15026653
# Iteration 49, loss = 0.14204516
# Iteration 50, loss = 0.13235686
# Iteration 51, loss = 0.12343497
# Iteration 52, loss = 0.11934348
# Iteration 53, loss = 0.10992321
# Iteration 54, loss = 0.10506161
# Iteration 55, loss = 0.09623456
# Iteration 56, loss = 0.08827191
# Iteration 57, loss = 0.08276998
# Iteration 58, loss = 0.07548746
# Iteration 59, loss = 0.07016911
# Iteration 60, loss = 0.06574940
# Iteration 61, loss = 0.06080267
# Iteration 62, loss = 0.05551720
# Iteration 63, loss = 0.05107111
# Iteration 64, loss = 0.04763774
# Iteration 65, loss = 0.04380047
# Iteration 66, loss = 0.04045956
# Iteration 67, loss = 0.03732207
# Iteration 68, loss = 0.03491166
# Iteration 69, loss = 0.03213921
# Iteration 70, loss = 0.03001239
# Iteration 71, loss = 0.02777070
# Iteration 72, loss = 0.02583439
# Iteration 73, loss = 0.02386177
# Iteration 74, loss = 0.02259188
# Iteration 75, loss = 0.02084886
# Iteration 76, loss = 0.01945358
# Iteration 77, loss = 0.01827150
# Iteration 78, loss = 0.01711520
# Iteration 79, loss = 0.01609395
# Iteration 80, loss = 0.01521688
# Iteration 81, loss = 0.01410097
# Iteration 82, loss = 0.01351383
# Iteration 83, loss = 0.01261592
# Iteration 84, loss = 0.01192860
# Iteration 85, loss = 0.01134285
# Iteration 86, loss = 0.01067189
# Iteration 87, loss = 0.01022267
# Iteration 88, loss = 0.00964932
# Iteration 89, loss = 0.00919885
# Iteration 90, loss = 0.00870895
# Iteration 91, loss = 0.00831823
# Iteration 92, loss = 0.00792474
# Iteration 93, loss = 0.00756062
# Iteration 94, loss = 0.00721232
# Iteration 95, loss = 0.00695764
# Iteration 96, loss = 0.00661778
# Iteration 97, loss = 0.00636985
# Iteration 98, loss = 0.00621132
# Iteration 99, loss = 0.00584734
# Iteration 100, loss = 0.00562417
# Iteration 101, loss = 0.00540344
# Iteration 102, loss = 0.00529837
# Iteration 103, loss = 0.00500098
# Iteration 104, loss = 0.00483304
# Iteration 105, loss = 0.00466259
# Iteration 106, loss = 0.00449608
# Iteration 107, loss = 0.00433748
# Iteration 108, loss = 0.00418846
# Iteration 109, loss = 0.00404437
# Iteration 110, loss = 0.00391274
# Iteration 111, loss = 0.00378345
# Iteration 112, loss = 0.00365581
# Iteration 113, loss = 0.00353694
# Iteration 114, loss = 0.00344332
# Iteration 115, loss = 0.00332309
# Iteration 116, loss = 0.00321559
# Iteration 117, loss = 0.00312325
# Iteration 118, loss = 0.00303001
# Iteration 119, loss = 0.00293584
# Iteration 120, loss = 0.00285951
# Iteration 121, loss = 0.00277962
# Iteration 122, loss = 0.00269441
# Iteration 123, loss = 0.00261629
# Iteration 124, loss = 0.00254340
# Iteration 125, loss = 0.00247500
# Iteration 126, loss = 0.00240917
# Iteration 127, loss = 0.00234821
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100, 40, 100), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=1000,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=None, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=True,
#               warm_start=False)

# %%
predictions = mlp.predict(X_test)
probs = mlp.predict_proba(X_test)
analize_data(X_test,y_test,predictions,probs)
# Out:
#                  Predicted Negative  Predicted Positive
# Actual Negative                  35                  26
# Actual Positive                  22                 117
#
#
#               precision    recall  f1-score   support
#
#            0       0.61      0.57      0.59        61
#            1       0.82      0.84      0.83       139
#
#     accuracy                           0.76       200
#    macro avg       0.72      0.71      0.71       200
# weighted avg       0.76      0.76      0.76       200

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train, y_train)
predictions = gnb.predict(X_test)
probs = gnb.predict_proba(X_test)
analize_data(X_test,y_test,predictions,probs)
# Out:
#                  Predicted Negative  Predicted Positive
# Actual Negative                  38                  23
# Actual Positive                  30                 109
#
#
#               precision    recall  f1-score   support
#
#            0       0.56      0.62      0.59        61
#            1       0.83      0.78      0.80       139
#
#     accuracy                           0.73       200
#    macro avg       0.69      0.70      0.70       200
# weighted avg       0.74      0.73      0.74       200

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier(n_estimators=500)
rfc.fit(X_train,y_train)
predictions = rfc.predict(X_test)
probs = rfc.predict_proba(X_test)
analize_data(X_test,y_test,predictions,probs)
# Out:
#                  Predicted Negative  Predicted Positive
# Actual Negative                  29                  32
# Actual Positive                   6                 133
#
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.48      0.60        61
#            1       0.81      0.96      0.88       139
#
#     accuracy                           0.81       200
#    macro avg       0.82      0.72      0.74       200
# weighted avg       0.81      0.81      0.79       200

# %% [markdown]
# Features research

# %%
Features=list(zip(X.columns,rfc.feature_importances_))
Features.sort(key=lambda b: b[1],reverse=True)
Features
# Out:
# [('creditamount', 0.13118315809224645),
#  ('age', 0.10663847900658054),
#  ('existingchecking', 0.106443711875334),
#  ('duration', 0.10056765819837947),
#  ('purpose', 0.06545955295300988),
#  ('credithistory', 0.06317265566406863),
#  ('employmentsince', 0.050432853188642233),
#  ('savings', 0.045096663057263016),
#  ('property', 0.044215447958302),
#  ('installmentrate', 0.0436682264817424),
#  ('residencesince', 0.041699626288996844),
#  ('statussex', 0.037435914903312356),
#  ('job', 0.030489988438560194),
#  ('otherinstallmentplans', 0.02787750879882115),
#  ('housing', 0.025706952299710494),
#  ('existingcredits', 0.02145032810308562),
#  ('telephone', 0.019945083850660437),
#  ('otherdebtors', 0.019308157698726083),
#  ('peopleliable', 0.01461292019930913),
#  ('foreignworker', 0.004595112943249079)]

# %%
mostImportantFeatures=[x for x in Features if x[1]>np.mean(rfc.feature_importances_)]
mostImportantFeatures
# Out:
# [('creditamount', 0.13118315809224645),
#  ('age', 0.10663847900658054),
#  ('existingchecking', 0.106443711875334),
#  ('duration', 0.10056765819837947),
#  ('purpose', 0.06545955295300988),
#  ('credithistory', 0.06317265566406863),
#  ('employmentsince', 0.050432853188642233)]

# %% [markdown]
# Histograms

# %%
plot_hist('classification','creditamount',data,50,(16,10),True)

# %%
plot_hist('classification','existingchecking',data,10,(5,5))

# %% [raw]
#  Status of existing checking account
#            A11 :      ... <    0 DM
# 	       A12 : 0 <= ... <  200 DM
# 	       A13 :      ... >= 200 DM /salary assignments for at least 1 year
#            A14 : no checking account

# %%
plot_hist('classification','age',data,30,(15,5),True)

# %%
plot_hist('classification','duration',data,20,(15,5),True)

# %%
plot_hist('classification','purpose',data,20,(15,5))

# %% [raw]
#  Purpose
# 	      A40 : car (new)
# 	      A41 : car (used)
# 	      A42 : furniture/equipment
# 	      A43 : radio/television
# 	      A44 : domestic appliances
# 	      A45 : repairs
# 	      A46 : education
# 	      A47 : (vacation - does not exist?)
# 	      A48 : retraining
# 	      A49 : business
# 	      A410 : others

# %%
plot_hist('classification','credithistory',data,20,(15,5))

# %% [raw]
#     Credit history
# 	      A30 : no credits taken/all credits paid back duly
#           A31 : all credits at this bank paid back duly
# 	      A32 : existing credits paid back duly till now
#           A33 : delay in paying off in the past
# 	      A34 : critical account/other credits existing (not at this bank)

# %%
plot_hist('classification','employmentsince',data,20,(15,5))

# %% [raw]
# Present employment since
# 	      A71 : unemployed
# 	      A72 :       ... < 1 year
# 	      A73 : 1  <= ... < 4 years
# 	      A74 : 4  <= ... < 7 years
# 	      A75 :       .. >= 7 years

# %% [markdown]
# ADDITIONAL RESEARCH

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
dtree=DecisionTreeClassifier()
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
cn=['good','bad']
fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (4,4), dpi=1200)
tree.plot_tree(dtree, 
               class_names=cn,
               feature_names =numvars+catvars,
               filled = True)
fig.savefig('imagename.png')

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=2)
pca.fit(X)
x_pca=pca.transform(X)
x_pca.shape,X.shape
# Out:
# ((1000, 2), (1000, 20))

# %%
plt.figure(figsize=(15,5))
plt.scatter(x_pca[:,0],x_pca[:,1],c=y)

# %%
import seaborn as sb
components=pd.DataFrame(pca.components_,columns=numvars+catvars)
components
plt.figure(figsize=(15,5))
sb.heatmap(components,cmap='plasma')

# %%
plot_hist('classification','savings',data,20,(15,5))

# %% [raw]
#  Savings account/bonds
# 	      A61 :          ... <  100 DM
# 	      A62 :   100 <= ... <  500 DM
# 	      A63 :   500 <= ... < 1000 DM
# 	      A64 :          .. >= 1000 DM
#           A65 :   unknown/ no savings account

# %%
plt.figure(figsize=(15,10))
sb.heatmap(data_prep.corr());
